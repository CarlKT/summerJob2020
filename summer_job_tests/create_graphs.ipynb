# %%
###Imports###
import sys
import os
from sklearn.datasets import load_iris

# %%
working_dir = '/Users/carlkristoftessier/Documents/all_that_programming/summer_job_tests/'
os.chdir(working_dir)

# %%
features, labels = load_iris(return_X_y=True)
# Out:
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.  3.6 1.4 0.2]
#  [5.4 3.9 1.7 0.4]
#  [4.6 3.4 1.4 0.3]
#  [5.  3.4 1.5 0.2]
#  [4.4 2.9 1.4 0.2]
#  [4.9 3.1 1.5 0.1]
#  [5.4 3.7 1.5 0.2]
#  [4.8 3.4 1.6 0.2]
#  [4.8 3.  1.4 0.1]
#  [4.3 3.  1.1 0.1]
#  [5.8 4.  1.2 0.2]
#  [5.7 4.4 1.5 0.4]
#  [5.4 3.9 1.3 0.4]
#  [5.1 3.5 1.4 0.3]
#  [5.7 3.8 1.7 0.3]
#  [5.1 3.8 1.5 0.3]
#  [5.4 3.4 1.7 0.2]
#  [5.1 3.7 1.5 0.4]
#  [4.6 3.6 1.  0.2]
#  [5.1 3.3 1.7 0.5]
#  [4.8 3.4 1.9 0.2]
#  [5.  3.  1.6 0.2]
#  [5.  3.4 1.6 0.4]
#  [5.2 3.5 1.5 0.2]
#  [5.2 3.4 1.4 0.2]
#  [4.7 3.2 1.6 0.2]
#  [4.8 3.1 1.6 0.2]
#  [5.4 3.4 1.5 0.4]
#  [5.2 4.1 1.5 0.1]
#  [5.5 4.2 1.4 0.2]
#  [4.9 3.1 1.5 0.2]
#  [5.  3.2 1.2 0.2]
#  [5.5 3.5 1.3 0.2]
#  [4.9 3.6 1.4 0.1]
#  [4.4 3.  1.3 0.2]
#  [5.1 3.4 1.5 0.2]
#  [5.  3.5 1.3 0.3]
#  [4.5 2.3 1.3 0.3]
#  [4.4 3.2 1.3 0.2]
#  [5.  3.5 1.6 0.6]
#  [5.1 3.8 1.9 0.4]
#  [4.8 3.  1.4 0.3]
#  [5.1 3.8 1.6 0.2]
# ...

# %%
# !python3 train_cross_val_example.py is_iris features labels
print(results)
# Out:
# Total fit time: 0.012482881546020508
# Total score time: 0.021419286727905273
# Performance:
#         ROC  Precision Score
# 0  0.988333         0.978074
# 1  1.000000         1.000000
# 2  0.996667         0.993939
# 3  1.000000         1.000000
# 4  0.986667         0.976242
# [array([[9.11018402e-01, 8.89773968e-02, 4.20100505e-06],
#        [7.56572291e-01, 2.43422798e-01, 4.91110597e-06],
#        [8.31471169e-01, 1.68524467e-01, 4.36320887e-06],
#        [7.90074523e-01, 2.09920325e-01, 5.15140966e-06],
#        [9.30398804e-01, 6.95971807e-02, 4.01483127e-06],
#        [9.69212673e-01, 3.07716712e-02, 1.56562029e-05],
#        [8.91926850e-01, 1.08064708e-01, 8.44202156e-06],
#        [8.85350983e-01, 1.14644325e-01, 4.69257144e-06],
#        [7.18563268e-01, 2.81431719e-01, 5.01280476e-06],
#        [7.83958228e-01, 2.16039111e-01, 2.66103971e-06],
#        [9.44915796e-01, 5.50801051e-02, 4.09898071e-06],
#        [8.83025695e-01, 1.16969270e-01, 5.03422444e-06],
# ...

# %%
def create_heatmap(features, average_feature=True):
    print(features.shape)
    #if average_feature:

# %%
print(results)
create_heatmap(results[3])
# Out:
# ['Total fit time: 0.017406702041625977', 'Total score time: 0.03903007507324219', 'Performance:', '        ROC  Precision Score', '0  0.988333         0.978074', '1  1.000000         1.000000', '2  0.996667         0.993939', '3  1.000000         1.000000', '4  0.986667         0.976242', '(array([0.98833333, 1.        , 0.99666667, 1.        , 0.98666667]), array([0.97807369, 1.        , 0.99393939, 1.        , 0.97624218]),            0         1         2         3         4', '0   0.000000  0.000000  0.000000  0.000000  0.000000', '1   1.157219  1.165304  0.980702  1.112965  1.096870', '2  -3.896911 -4.174523 -4.211439 -4.151491 -4.048803', '3  -0.294132  0.000000  0.000000  0.000000 -0.156708', '4   0.000000  0.000000  0.347409  0.129157  0.187292', '5  -1.259644 -1.147672 -1.127915 -1.072946 -1.299869', '6   0.407737  0.534157  0.000000  0.628280  0.330768', '7  -0.385930 -0.523111 -0.313491 -0.704094 -0.515964', '8   0.000000  0.000000  0.000000  0.000000  0.000000', '9  -0.28
# ...
